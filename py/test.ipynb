# %%
import pandas as pd

path = r"C:\Users\raphael.almeida\Downloads\download (1).xlsx"

df = pd.read_excel(path)

df = pd.DataFrame(df)

df
# Out:
#          Date                                       CustomeName  Registration  \
# 0  2025-07-02         S M FERREIRA TRANSPORTES E LOGISTICA LTDA         10910
# 1  2025-07-02         S M FERREIRA TRANSPORTES E LOGISTICA LTDA         10910
# 2  2025-07-02         S M FERREIRA TRANSPORTES E LOGISTICA LTDA         10910
# 3  2025-07-02         S M FERREIRA TRANSPORTES E LOGISTICA LTDA         10910
# 4  2025-07-02                               ANDRE LUCIANO BUENO         10931
# 5  2025-07-02                               ANDRE LUCIANO BUENO         10931
# 6  2025-07-02                 CARLOS ALBERTO PADILHA HOLLEWEGER         10917
# 7  2025-07-02  CENTRO DE FORMACAO DE CONDUTORES ENTRE RIOS LTDA         10930
# 8  2025-07-02  CENTRO DE FORMACAO DE CONDUTORES ENTRE RIOS LTDA         10930
# 9  2025-07-02                         CRISTIAN ROBERTO PASQUALI         10924
# 10 2025-07-02                         CRISTIAN ROBERTO PASQUALI         10924
# ...

# %%
df['SetReg'].nunique()
# Out:
# 19
